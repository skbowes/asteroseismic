# %%
import matplotlib.pyplot as plt
import phoebe as pb
from phoebe import u
import pandas as pd

# %%
logger = pb.logger()
b = pb.default_binary()

# %%
df = pd.read_csv("./TIC_465088681_sec12.csv", sep="\t")
# df = pd.read_csv("./TIC_465088681_200.csv", sep="\t")
watts_units = u.W / (u.m * u.m)
flux =df['flux']
time = df['time']
sigma = df['flux_err']

# %%
#system 
b["ecc@binary"] = 0.26
b["q@binary"] = 0.11
b["sma@binary"] = 40 * u.solRad
b["incl@binary"] = 79.5
b["per0"] = 311 *u.deg
b["period@binary"] = 5.952 *u.day
b['t0_supconj@component'] = 1629

b.add_dataset('lc', dataset='lc01', fluxes=flux.values*watts_units, times=time.values*u.day, sigmas = sigma.values*watts_units, overwrite=True)

#primary
# b["mass@primary@component"] = 13.5 #according to 2006, 10.4 but higher for more recent: 14.5 +/- 1.1
# b.flip_constraint("sma@binary", solve_for="mass")
b["requiv@primary"] = 8.8 #2013: 8.8; 
b["teff@primary"] = 25000
b["gravb_bol@primary"] = 1.0
b["irrad_frac_refl_bol@primary"] = 1.0
# b.flip_constraint("logg@primary", solve_for="requiv@primary")
# b["logg@primary@star@component"] = 3.8
# b.flip_constraint("requiv@primary",solve_for="logg@primary")

#secondary
# b.flip_constraint("mass@secondary", solve_for="q")
# b["mass@secondary@component"] = 1.8

# b.flip_constraint("q@binary", solve_for="mass")
b["requiv@secondary@component"] = 1.3 #1.5+/-0.2
# b['teffratio@binary'] = 0.21
b["teff@secondary@component"] = 6000

b["gravb_bol@secondary"] = 0.7
b["irrad_frac_refl_bol@secondary"] = 0.7

#atmosphere
b.set_value_all("ld_mode", "manual")
b.set_value_all("ld_mode_bol", "manual")
b.set_value_all("atm", "ck2004")
b.set_value('pblum_mode', 'component-coupled')
# b.set_value('pblum_mode', 'dataset-coupled')

# %%
# b.flip_constraint("requiv@primary",solve_for="requivratio@binary")
# b['requivratio@binary@orbit@component'] = 0.17
# b["teff@secondary@component"] = 5000
# b["gravb_bol@secondary"] = 0.7
# b["irrad_frac_refl_bol@secondary"] = 0.7
# # b["mass@secondary@component"] = 0.8
# # b["q@binary"] = 0.17
# b["requiv@secondary@component"] = 1.3
b.add_compute('ellc', compute='fastcompute', overwrite=True)
b.compute_pblums(compute='fastcompute', dataset='lc01', pbflux=True)
# Out:
# {'pblum@primary@lc01': <Quantity 12.56637061 W>,
#  'pblum@secondary@lc01': <Quantity 0.00984093 W>,
#  'pbflux@lc01': <Quantity 1.00078312 W / m2>}

# %%
print(b.filter("pblum_method"))
# Out:
# ParameterSet: 1 parameters
#    pblum_method@fastcompute@co...: stefan-boltzmann

# %%
# b["incl@binary"] = 90
# b["q@binary"] = 0.1
# b["requiv@primary"] = 9.2
# b["teff@secondary@component"] = 6000
# b['t0_supconj@component'] = 1629
b["sma@binary"] = 40 * u.solRad
b.set_value('pblum_method', 'phoebe')
b.run_compute('phoebe01')
b.plot(x='phase', show=True)
b.plot(show=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 554/554 [00:13<00:00, 41.17it/s]
# (<autofig.figure.Figure | 1 axes | 2 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b.flip_constraint("esinw@binary@orbit", solve_for='ecc')
b.flip_constraint("ecosw@binary@orbit", solve_for='per0')
b.flip_constraint("teffratio@binary@orbit", solve_for='teff@primary')
b.flip_constraint('requivratio@binary', solve_for='requiv@primary')
b.flip_constraint("requivsumfrac@binary@orbit", solve_for='requiv@secondary')
# Out:
# <ConstraintParameter: {requiv@secondary@component} = (({requivratio@binary@component} * {requivsumfrac@binary@component}) * {sma@binary@component}) / ({requivratio@binary@component} + 1.000000) (solar units) => 1.3 solRad>

# %%
print(b.get_parameter(qualifier='pblum_mode', dataset='lc01'))
# Out:
# Parameter: pblum_mode@lc01@dataset
#                        Qualifier: pblum_mode
#                      Description: Mode for scaling passband luminosities
#                            Value: component-coupled
#                          Choices: decoupled, component-coupled, dataset-coupled, dataset-scaled, absolute
#                   Constrained by:
#                       Constrains: None
#                       Related to: None

# %%
b.add_compute('ellc', compute='fastcompute', overwrite=True)
pblums_scaled = b.compute_pblums(compute='fastcompute')
print(pblums_scaled)
# Out:
# {'pblum@primary@lc01': <Quantity 12.56637061 W>, 'pblum@secondary@lc01': <Quantity 0.00984093 W>}

# %%
b.set_value_all('pblum_mode', 'component-coupled')
b.set_value('pblum', dataset='lc01', component='primary', value=pblums_scaled['pblum@primary@lc01'])
print(b.compute_pblums(compute='fastcompute', pblum_method='phoebe', dataset='lc01', pbflux=True))
# Out:
# {'pblum@primary@lc01': <Quantity 12.56637061 W>, 'pblum@secondary@lc01': <Quantity 0.00983762 W>, 'pbflux@lc01': <Quantity 1.00078285 W / m2>}

# %%
b.save("6.bundle")
# Out:
# '6.bundle'

# %%
b.run_compute("phoebe01")
b.plot(show=True)
b.plot(x='phase', show=True)
### blue is synthetic, black is data
# Out:
# Tue, 15 Aug 2023 14:21 BUNDLE       WARNING overwriting model: latest
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 554/554 [00:14<00:00, 39.06it/s]
# (<autofig.figure.Figure | 1 axes | 2 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b['teff@secondary']
# Out:
# <Parameter: teff=7000.0 K | keys: description, value, quantity, default_unit, limits, visible_if, copy_for, readonly, advanced, latexfmt>

# %%
# Out:
# <ConstraintParameter: {requiv@secondary@component} = (({requivratio@binary@component} * {requivsumfrac@binary@component}) * {sma@binary@component}) / ({requivratio@binary@component} + 1.000000) (solar units) => 1.3 solRad>

# %%
b.add_solver('estimator.ebai', solver='ebaiest', ebai_method = 'mlp', overwrite=True)
b['phase_bin@ebaiest@solver'] = False
b.run_solver(solver='ebaiest',  model='ebai_model', solution= "ebaiest_sol", kind='ebai', overwrite=True)
print(b.adopt_solution('ebaiest_sol',  model='ebai_model',trial_run=True))
# b.adopt_solution('ebaiest_sol')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       2 b['phase_bin@ebaiest@solver'] = False
#       3 b.run_solver(solver='ebaiest',  model='ebai_model', solution= "ebaiest_sol", kind='ebai', overwrite=True)
# ----> 4 print(b.adopt_solution('ebaiest_sol',  model='ebai_model',trial_run=True))
#
# File ~/anaconda3/lib/python3.10/site-packages/phoebe/frontend/bundle.py:13771, in Bundle.adopt_solution(self, solution, adopt_parameters, adopt_distributions, adopt_values, trial_run, remove_solution, return_changes, **kwargs)
#   13769 solver_kind = solution_ps.kind
#   13770 if solver_kind is None:
# > 13771     raise ValueError("could not find solution='{}'".format(solution))
#   13773 if not (adopt_distributions is None or isinstance(adopt_distributions, bool)):
#   13774     raise TypeError("adopt_distributions must be None or bool.  To set the label of the resulting distribution, use distribution instead.")
#
# ValueError: could not find solution='ebaiest_sol'

# %%
b.plot(x='phases', linestyle={'model': 'solid'},
           color={'ebai_model': 'red'},
           save='figure_ebai.pdf',
           show=True)
# Out:
# (<autofig.figure.Figure | 1 axes | 2 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
print(b["mass@primary"])
# Out:
# ParameterSet: 2 parameters
# C          mass@primary@component: 21.838247429753796 solMass
#           mass@primary@constraint: (39.478418 * ({sma@binary@component} ** 3.000000)) / ((({period@binary@component} ** 2.000000) * ({q@binary@component} + 1.000000)) * 2942.206217504419328179210424423218)

# %%
b.run_compute(model = 'ebai_model')
b.plot(show=True)
# Out:
# Wed, 09 Aug 2023 10:51 PASSBANDS    WARNING Online passbands unavailable (reached max tries).  Pass refresh=True to force another attempt or repeat_errors=False to avoid showing this message.
# 100%|████████████████████████████████████████████████████████████████████████████████████| 554/554 [00:12<00:00, 43.12it/s]
# (<autofig.figure.Figure | 1 axes | 3 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b.add_solver('optimizer.nelder_mead', solver='nm_solver')
# Out:
# <ParameterSet: 14 parameters | qualifiers: fit_parameters, adaptive, priors, progress_every_niters, initial_values, xatol, comments, fatol, maxiter, priors_combine, expose_lnprobabilities, use_server, compute, continue_from>

# %%
# print(b.filter(solver='nm_solver'))
b.add_compute('ellc', compute='fastcompute', overwrite=True)
b.set_value('compute', solver='nm_solver', value='fastcompute')
# b.set_value('compute', solver='nm_solver', value='phoebe01')
# ValueError: value for compute@nm_solver@solver must be one of ['phoebe01'], not 'fastcompute'
b.set_value('maxiter', 1000)
# b.set_value('maxfev', 1000)
# print(b.get_parameter('fit_parameters'))

# %%
b.set_value('fit_parameters', ['requivratio', 'sma@binary', 'teffratio@binary', "q@binary"])
b.get_value('fit_parameters', expand=True)
# Out:
# ['requivratio@binary@orbit@component',
#  'sma@binary@orbit@component',
#  'teffratio@binary@orbit@component',
#  'q@binary@orbit@component']

# %%
b.run_solver('nm_solver', solution='nm_sol_many', overwrite=True)
# Out:
#   1%|██▉                                                                                                                                                                                                                                                                             | 11/1000 [00:05<06:25,  2.57it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.015100494384765843 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   1%|███▎                                                                                                                                                                                                                                                                            | 12/1000 [00:05<05:52,  2.80it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.015100494384765836 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   1%|███▌                                                                                                                                                                                                                                                                            | 13/1000 [00:05<05:30,  2.99it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.007381099700927929 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   1%|███▊                                                                                                                                                                                                                                                                            | 14/1000 [00:05<05:14,  3.14it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.022834559917450144 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   2%|████                                                                                                                                                                                                                                                                            | 15/1000 [00:06<05:03,  3.25it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.003486336171627226 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   2%|████▎                                                                                                                                                                                                                                                                           | 16/1000 [00:06<04:55,  3.33it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.008794538311660466 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   2%|████▌                                                                                                                                                                                                                                                                           | 17/1000 [00:06<04:57,  3.30it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING secondary is overflowing at periastron (requiv=1.8968919843679297, requiv_max=1.3349391769491301).  Use contact model if overflowing is desired.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: failed to pass checks
# Run Checks Report: FAIL
# ERROR: secondary is overflowing at periastron (requiv=1.8968919843679297, requiv_max=1.3349391769491301).  Use contact model if overflowing is desired. (4 affected parameters, affecting system,run_compute).  lnprobability=-inf
#   2%|████▉                                                                                                                                                                                                                                                                           | 18/1000 [00:07<05:45,  2.84it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.0013117294505938723 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   2%|█████▍                                                                                                                                                                                                                                                                          | 20/1000 [00:07<05:04,  3.22it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.002625547196097788 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   2%|█████▋                                                                                                                                                                                                                                                                          | 21/1000 [00:08<04:55,  3.32it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING secondary is overflowing at periastron (requiv=1.8220875959167282, requiv_max=1.769448609239281).  Use contact model if overflowing is desired.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: failed to pass checks
# Run Checks Report: FAIL
# ERROR: secondary is overflowing at periastron (requiv=1.8220875959167282, requiv_max=1.769448609239281).  Use contact model if overflowing is desired. (4 affected parameters, affecting system,run_compute).  lnprobability=-inf
#   2%|██████▌                                                                                                                                                                                                                                                                         | 24/1000 [00:09<07:10,  2.26it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.0013100413961110759 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   3%|███████▉                                                                                                                                                                                                                                                                        | 29/1000 [00:11<06:48,  2.38it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39400.76186793], logg=[3.86786778], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   3%|████████▏                                                                                                                                                                                                                                                                       | 30/1000 [00:12<07:01,  2.30it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.001435444692720951 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   3%|████████▍                                                                                                                                                                                                                                                                       | 31/1000 [00:12<06:16,  2.58it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39155.60881758], logg=[3.90458937], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   3%|████████▋                                                                                                                                                                                                                                                                       | 32/1000 [00:13<06:39,  2.42it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.00027631370791997636 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   3%|████████▉                                                                                                                                                                                                                                                                       | 33/1000 [00:13<06:02,  2.67it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[35750.92862572], logg=[3.93415341], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   3%|█████████▏                                                                                                                                                                                                                                                                      | 34/1000 [00:13<06:29,  2.48it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.0003231295081613031 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   4%|█████████▌                                                                                                                                                                                                                                                                      | 35/1000 [00:14<05:53,  2.73it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[36192.44574019], logg=[3.91864671], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   4%|█████████▊                                                                                                                                                                                                                                                                      | 36/1000 [00:14<06:23,  2.51it/s]Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error while setting values: value of q=-0.004532867325017356 not within limits of [<Quantity 0.>, None]. lnprobability=-inf
#   4%|██████████                                                                                                                                                                                                                                                                      | 37/1000 [00:14<05:50,  2.75it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[38217.50741677], logg=[3.93086326], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   4%|██████████▎                                                                                                                                                                                                                                                                     | 38/1000 [00:15<06:20,  2.53it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[35973.15891385], logg=[3.94268093], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   4%|██████████▌                                                                                                                                                                                                                                                                     | 39/1000 [00:15<06:50,  2.34it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING secondary is overflowing at periastron (requiv=1.3241554275322478, requiv_max=0.7407331170623248).  Use contact model if overflowing is desired.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: failed to pass checks
# Run Checks Report: FAIL
# ERROR: secondary is overflowing at periastron (requiv=1.3241554275322478, requiv_max=0.7407331170623248).  Use contact model if overflowing is desired. (4 affected parameters, affecting system,run_compute).  lnprobability=-inf
#   4%|███████████▉                                                                                                                                                                                                                                                                    | 44/1000 [00:18<07:10,  2.22it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[36438.05746148], logg=[3.9075526], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   5%|████████████▌                                                                                                                                                                                                                                                                   | 46/1000 [00:19<07:45,  2.05it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[35655.52454899], logg=[3.87933382], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#   5%|█████████████▊                                                                                                                                                                                                                                                                  | 51/1000 [00:21<07:45,  2.04it/s]Tue, 15 Aug 2023 13:43 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[35243.80831706], logg=[3.8723575], abun=[0.]
# Tue, 15 Aug 2023 13:43 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  15%|████████████████████████████████████████▋                                                                                                                                                                                                                                      | 150/1000 [01:04<06:36,  2.14it/s]Tue, 15 Aug 2023 13:44 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[42530.85796769], logg=[4.08879241], abun=[0.]
# Tue, 15 Aug 2023 13:44 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  15%|█████████████████████████████████████████▏                                                                                                                                                                                                                                     | 152/1000 [01:05<05:48,  2.43it/s]Tue, 15 Aug 2023 13:44 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[43372.66978076], logg=[4.08365549], abun=[0.]
# Tue, 15 Aug 2023 13:44 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  16%|██████████████████████████████████████████                                                                                                                                                                                                                                     | 155/1000 [01:06<05:44,  2.45it/s]Tue, 15 Aug 2023 13:44 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[42306.37266876], logg=[4.07621032], abun=[0.]
# Tue, 15 Aug 2023 13:44 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  30%|█████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                             | 301/1000 [02:11<04:28,  2.60it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39399.65379455], logg=[5.0760719], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  30%|█████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                                                             | 302/1000 [02:12<04:46,  2.43it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39412.49380132], logg=[5.08848125], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  30%|██████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                             | 303/1000 [02:12<04:59,  2.33it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39397.08366614], logg=[5.07363363], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  30%|██████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                                                            | 304/1000 [02:13<05:09,  2.25it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39337.91026394], logg=[5.01102775], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  30%|██████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                                            | 305/1000 [02:13<05:18,  2.18it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39369.93877851], logg=[5.04597401], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|██████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                                            | 306/1000 [02:14<05:22,  2.15it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39352.46221708], logg=[5.02725714], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|███████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                                           | 307/1000 [02:14<05:30,  2.10it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39360.29551931], logg=[5.03568929], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|███████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                                                           | 308/1000 [02:15<05:32,  2.08it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39340.11597387], logg=[5.01348699], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|███████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                                           | 309/1000 [02:15<05:44,  2.01it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39341.50828813], logg=[5.01502862], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                           | 310/1000 [02:16<05:43,  2.01it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39331.59951623], logg=[5.0037319], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                                                                          | 311/1000 [02:16<06:33,  1.75it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39331.0570703], logg=[5.0030902], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                          | 312/1000 [02:17<06:12,  1.85it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39342.33809935], logg=[5.01602613], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                                                          | 313/1000 [02:17<06:01,  1.90it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39340.16210298], logg=[5.01354738], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  31%|█████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                          | 314/1000 [02:18<05:59,  1.91it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39341.02916984], logg=[5.01452454], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|█████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                                                                         | 315/1000 [02:18<05:48,  1.96it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39335.09405119], logg=[5.00777199], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|█████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                                         | 316/1000 [02:19<05:44,  1.99it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39334.78568788], logg=[5.00741684], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|█████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                                         | 317/1000 [02:19<05:39,  2.01it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39331.7803073], logg=[5.0039537], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|██████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                                        | 318/1000 [02:20<05:39,  2.01it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39331.25051369], logg=[5.00333961], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|██████████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                                                        | 319/1000 [02:20<05:38,  2.01it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39329.68181795], logg=[5.00151817], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|██████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                                        | 320/1000 [02:21<05:33,  2.04it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39329.22087209], logg=[5.00098115], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|███████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                                                                       | 322/1000 [02:22<04:50,  2.33it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39330.06118025], logg=[5.00195931], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|███████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                       | 323/1000 [02:22<05:00,  2.25it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39328.79781001], logg=[5.00049668], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  32%|████████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                       | 325/1000 [02:23<04:28,  2.51it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39330.06552784], logg=[5.00197484], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  33%|████████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                                                                      | 326/1000 [02:23<04:45,  2.36it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39329.59229782], logg=[5.0014289], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  33%|████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                      | 327/1000 [02:24<04:56,  2.27it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39329.3172404], logg=[5.00110358], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  33%|████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                                      | 328/1000 [02:24<05:03,  2.21it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39329.04625148], logg=[5.00078944], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  33%|█████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                                     | 329/1000 [02:25<05:08,  2.17it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39328.87485299], logg=[5.00058728], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  33%|█████████████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                                                     | 330/1000 [02:25<05:10,  2.16it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39328.71793655], logg=[5.00040477], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  34%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                    | 336/1000 [02:28<05:10,  2.14it/s]Tue, 15 Aug 2023 13:45 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39328.67890551], logg=[5.00045672], abun=[0.]
# Tue, 15 Aug 2023 13:45 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  37%|████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                                          | 372/1000 [02:43<03:51,  2.71it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39332.93593339], logg=[5.00687007], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  37%|█████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                          | 373/1000 [02:44<04:11,  2.49it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39332.76814178], logg=[5.00687791], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|█████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                         | 375/1000 [02:45<03:56,  2.65it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39330.58736498], logg=[5.00419819], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|█████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                         | 376/1000 [02:45<04:16,  2.43it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39329.96331589], logg=[5.00386473], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|██████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                        | 377/1000 [02:46<04:33,  2.28it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39330.30370385], logg=[5.00404667], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                        | 379/1000 [02:46<04:07,  2.51it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39327.96677087], logg=[5.00165344], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                        | 380/1000 [02:47<04:24,  2.35it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39330.00968033], logg=[5.00384166], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                       | 382/1000 [02:48<04:07,  2.50it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.68133389], logg=[5.00032354], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  38%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                                       | 383/1000 [02:48<04:25,  2.32it/s]Tue, 15 Aug 2023 13:46 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39327.58663437], logg=[5.00118713], abun=[0.]
# Tue, 15 Aug 2023 13:46 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
# ...
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                               | 766/1000 [05:37<01:50,  2.12it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05201541], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                               | 767/1000 [05:38<01:51,  2.08it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05198786], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  77%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                              | 769/1000 [05:39<01:36,  2.40it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05162661], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  77%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                              | 771/1000 [05:39<01:27,  2.61it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05157653], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  77%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                             | 773/1000 [05:40<01:23,  2.71it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.0519403], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  78%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                             | 775/1000 [05:41<01:21,  2.78it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05207156], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  78%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                            | 779/1000 [05:43<01:47,  2.05it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.0519567], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  78%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                           | 780/1000 [05:43<01:46,  2.07it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.0517889], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                          | 783/1000 [05:45<01:38,  2.20it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05186461], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                          | 784/1000 [05:45<01:39,  2.17it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05213559], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                          | 785/1000 [05:46<01:41,  2.12it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05198778], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  79%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                          | 786/1000 [05:46<01:41,  2.11it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05179541], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  79%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                         | 787/1000 [05:47<01:40,  2.11it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05190034], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  79%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                         | 790/1000 [05:48<01:46,  1.98it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05205523], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  79%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                        | 793/1000 [05:49<01:30,  2.30it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05200693], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  80%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                       | 795/1000 [05:50<01:21,  2.53it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.0519543], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  80%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                       | 797/1000 [05:51<01:31,  2.21it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05201887], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                      | 799/1000 [05:52<01:38,  2.03it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05193618], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                      | 800/1000 [05:53<01:37,  2.05it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05199551], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                      | 801/1000 [05:53<01:36,  2.06it/s]Tue, 15 Aug 2023 13:49 BUNDLE       WARNING Atmosphere parameters out of bounds: atm=ck2004, ldatm=ck2004, Teff=[39326.05192682], logg=[5.], abun=[0.]
# Tue, 15 Aug 2023 13:49 SOLVER       WARNING received error from run_compute: compute_pblums failed with pblum_method='stefan-boltzmann', atm='ck2004', ld_mode='manual' with an atmosphere out-of-bounds error when querying for Inorm. Enable 'warning' logger to see out-of-bound arrays..  lnprobability=-inf
#  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                     | 803/1000 [05:55<01:27,  2.26it/s]
# <ParameterSet: 11 parameters | qualifiers: fitted_values, niter, initial_values, fitted_units, adopt_values, comments, adopt_distributions, success, message, fitted_twigs, adopt_parameters>

# %%
b.run_compute(compute='fastcompute', sample_from='nm_sol_many', model='nm_model_many', overwrite=True)
# b.run_compute(compute='fastcompute', model='after_nm')
# Out:
# Tue, 15 Aug 2023 13:49 BUNDLE       WARNING all distributions are delta, using sample_size=1 instead of sample_size=10
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:18<00:00,  1.84s/it]
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# Connection to online passbands at http://tables.phoebe-project.org could not be established.  Check your internet connection or try again later (can manually call phoebe.list_online_passbands(refresh=True) to retry).  If the problem persists and you're using a Mac, you may need to update openssl (see http://phoebe-project.org/help/faq). Original error from urlopen: TimeoutError timed out
# <ParameterSet: 8 parameters | qualifiers: fluxes, comments, sample_mode, samples, failed_samples, sampled_twigs, times, sampled_uniqueids>

# %%
b.plot(x='phases', linestyle={'model': 'solid'},
           color={'nm_model_many': 'red', 'nm_model': 'green'},
#            save='figure_optimizer_nm.pdf',
           show=True)
# b.plot(x='phases', 
#            c={'after_estimators': 'red', 'after_nm': 'green', 'dataset': 'black'}, 
#            linestyle={'after_estimators': 'dashed', 'after_nm': 'solid'},
#            marker={'dataset': '.'},
#            save='figure_optimizer_nm.pdf', show=True)
# Out:
# (<autofig.figure.Figure | 1 axes | 3 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
# print(b.filter(solution='nm_sol'))
print(b.adopt_solution(solution='nm_sol_many', trial_run=True))
# b.adopt_solution(solution='nm_sol')
# Out:
# ParameterSet: 4 parameters
#    requivratio@binary@orbit@co...: 0.13452277567947224
#        sma@binary@orbit@component: 480.4967879955264 solRad
#    teffratio@binary@orbit@comp...: 0.15257061671289177
#          q@binary@orbit@component: 0.007447865280416082

# %%
print(b["mass@primary"])
print(b["mass@secondary"])
print(b["q@binary"])
print(b['requivratio'])
# Out:
# ParameterSet: 2 parameters
# C          mass@primary@component: 21.838247429753796 solMass
#           mass@primary@constraint: (39.478418 * ({sma@binary@component} ** 3.000000)) / ((({period@binary@component} ** 2.000000) * ({q@binary@component} + 1.000000)) * 2942.206217504419328179210424423218)
# ParameterSet: 2 parameters
# C        mass@secondary@component: 2.4022072172729176 solMass
#         mass@secondary@constraint: (39.478418 * ({sma@binary@component} ** 3.000000)) / ((({period@binary@component} ** 2.000000) * ((1.000000 / {q@binary@component}) + 1.000000)) * 2942.206217504419328179210424423218)
# Parameter: q@binary@component
#                        Qualifier: q
#                      Description: Mass ratio
#                            Value: 0.11
#                   Constrained by:
#                       Constrains: mass@primary@component, sma@primary@component, asini@primary@component, requiv_max@primary@component, mass@secondary@component, sma@secondary@component, asini@secondary@component, requiv_max@secondary@component
#                       Related to: sma@binary@component, period@binary@component, mass@primary@component, sma@primary@component, incl@binary@component, asini@primary@component, syncpar@primary@component, ecc@binary@component, incl@primary@component, long_an@primary@component, long_an@binary@component, requiv_max@primary@component, mass@secondary@component, sma@secondary@component, asini@secondary@component, syncpar@secondary@component, incl@secondary@component, long_an@secondary@component, requiv_max@secondary@component
#
# Parameter: requivratio@binary@component
#                        Qualifier: requivratio
#                      Description: ratio between equivalent radii of children stars
#                            Value: 0.1477272727272727
#                   Constrained by:
#                       Constrains: None
#                       Related to: sma@binary@component, requivsumfrac@binary@component

# %%
pblums_scaled = b.compute_pblums(compute='fastcompute', model='after_nm')
print(pblums_scaled)
b.set_value_all('pblum_mode', 'component-coupled')

# %%
b.set_value('pblum', dataset='lc01', component='primary', value=pblums_scaled['pblum@primary@lc01'])
print(b.compute_pblums(compute='fastcompute', dataset='lc01', pbflux=True))
#might need this?
b.flip_constraint('sma@binary', solve_for='asini')

# %%
b.save('6.bundle')
# Out:
# '6.bundle'

# %%
b.add_solver('sampler.emcee',
             compute='fastcompute',
             solver='emcee_solver', overwrite=True)
# Out:
# <ParameterSet: 17 parameters | qualifiers: expose_failed, progress_every_niters, burnin_factor, thin_factor, init_from_combine, init_from, nwalkers, use_server, compute, continue_from, comments, init_from_requires, priors_combine, nlags_factor, continue_from_iter, niters, priors>

# %%
b.add_distribution({'teffratio': pb.gaussian_around(0.1),
                    'requivsumfrac': pb.gaussian_around(0.1),
                    'incl@binary': pb.gaussian_around(3),
                    'sma@binary': pb.gaussian_around(2),
                    'q': pb.gaussian_around(0.1)},
#                     'ecc': pb.gaussian_around(0.5),
#                     'per0': pb.gaussian_around(1)},
                   'pblum': phoebe.uniform_around(0.5),
                    distribution='ball_around_optimized_solution', overwrite_all=True)

b.set_value('init_from', 'ball_around_optimized_solution')

# %%
## priors

b.add_distribution({"ecc@binary": pb.gaussian(0.26, 0.01),
                    "q@binary": pb.gaussian(5.77, 0.1)},
                   distribution='priors_from_external_source', overwrite_all=True)


b.set_value('priors@emcee_solver', 'priors_from_external_source')

# %%
b.plot_distribution_collection('ball_around_optimized_solution', show=True)

# %%
b.run_compute(compute='fastcompute', sample_from='ball_around_optimized_solution', 
              sample_num=20, model='init_from_model', overwrite=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:07<00:00,  2.52it/s]
# <ParameterSet: 9 parameters | qualifiers: failed_samples, comments, sample_mode, sampled_twigs, fluxes, times, sampled_uniqueids, samples, flux_scale>

# %%
b.plot(dataset='lc01', x='phases', 
           marker={'dataset': '.'},
           model='init_from_model', show=True)
# Out:
# (<autofig.figure.Figure | 1 axes | 2 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b.plot(dataset='lc01', x='phases', y='residuals',
           z={'dataset': 0, 'model': 1},
           model='init_from_model', show=True)
# Out:
# /Users/skbowes/anaconda3/lib/python3.10/site-packages/phoebe/dependencies/autofig/call.py:1305: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   artist = ax.scatter(*datapoint,
# (<autofig.figure.Figure | 1 axes | 2 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b.export_solver('initial_run_emcee.py',
                solver='emcee_solver',
                niters=1000, progress_every_niters=50,
                nwalkers=16,
                solution='emcee_sol',
                log_level='warning',
                pause=True)
# Out:
# Wed, 02 Aug 2023 15:11 BUNDLE       WARNING sampling with dataset-scaled can cause unintended issues.  Consider using component-coupled and marginalizing over pblum
# * optional:  call b.save(...) to save the bundle to disk, you can then safely close the active python session and recover the bundle with phoebe.load(...)
# * run inverse_run_emcee.py (within mpirun or on an external machine, if desired)
# * once completed, copy inverse_run_emcee.py.out to this directory, if necessary
# * press enter to exit this pause
# * call b.import_solution('inverse_run_emcee.py.out')
#
# (press enter to continue)
# ('inverse_run_emcee.py', 'inverse_run_emcee.py.out')

# %%
b.set_value('pblum', dataset='lc01', component='primary', value=pblums_scaled['pblum@primary@lc01'])
print(b.compute_pblums(compute='fastcompute', dataset='lc01', pbflux=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 b.set_value('pblum', dataset='lc01', component='primary', value=pblums_scaled['pblum@primary@lc01'])
#       2 print(b.compute_pblums(compute='fastcompute', dataset='lc01', pbflux=True))
#
# NameError: name 'pblums_scaled' is not defined

# %%
b.add_dataset('orb', compute_times=time.values*u.day)
# b.add_dataset('orb', compute_times=np.linspace(-1,1,1001))
b.run_compute(ltte=False)

# %%
print(b.get_parameter('fit_parameters'))

# %%
afig, mplfig = b.plot(time='t0_supconj', show=True)

# %%
print(b.filter('compute_phases'))

# %%
afig, mplfig = b.plot(projection='3d', show=True)

# %%
afig, mplfig = b.plot(x='times', show=True)
# u is a position on the sky

# %%
print(b.get_parameter(qualifier='us', component='primary', kind='orb', context='model'))

# %%
axs, artists = b.plot()

# %%
b.add_dataset('mesh', include_times= 'lc01')

# %%
b.set_value('compute_times', kind='mesh', value=[10])
b.set_value('include_times', kind='mesh', value=['lc01'])
b.set_value('columns', value=['teffs'])
b.run_compute()
# afig, mplfig = b.plot(kind='mesh', time=0.0, fc='teffs', ec='none', show=True)

# %%
#will generate figure without time, but nothing gets plotted.
afig, mplfig = b.plot(kind='mesh', time=, fc='teffs', ec='none', show=True)

# %%
afig, mplfig = b['lc01@model'].plot(x='phases', t0='t0_supconj', show=True)

# %%
b.add_solver('optimizer.nelder_mead')
print(b.run_checks())
b.run_solver(kind='nelder_mead')
# print run checks, see which parameters are failing

# %%
b.add_solver('estimator.ebai', solver='ebaiknn', ebai_method = 'knn', overwrite=True)
b['phase_bin@ebaiknn@solver'] = False
b.run_checks()
b.run_solver(solver='ebaiknn', solution= "ebaiknn_sol", kind='ebai', overwrite=True)
print(b.adopt_solution('ebaiknn_sol'))
b.adopt_solution('ebaiknn_sol')

# %%
b.flip_constraint("ecc@binary@orbit", solve_for='esinw')
b.flip_constraint("per0@binary@orbit", solve_for='ecosw')

b.add_solver('estimator.lc_geometry', solver= 'lc_geo', overwrite=True)
# b['analytical_model@lc_geo'] = 'two-gaussian' ##this throws up an error, requires additional arguments
b['analytical_model@lc_geo'] = 'polyfit'
# print(b.get_solver(solver='lc_geo'))
print(b.run_checks())
b.run_solver(solver = 'lc_geo', solution = 'lc_geo_sol', kind='lc_geometry', overwrite=True)
b.adopt_solution('lc_geo_sol')

# %%
b.add_solver('estimator.lc_periodogram', solver= 'lc_periodo', overwrite=True)
b.run_solver(solver= 'lc_periodo', solution = 'periodo_sol', kind='lc_periodogram', overwrite=True)
print(b.adopt_solution('periodo_sol'))
b.adopt_solution('periodo_sol')

b.run_compute()
b.plot(show=True)
b.plot(x='phase', show=True)

# %%
# b.filter(component='primary', context='constraint')
print(b.filter(qualifier='atm'))
# b.set_value("logg@secondary@component", value = 3.4)
print(b.get_parameter('atm@primary@phoebe01@phoebe@compute'))
# print(b.get_parameter('q@binary@component'))

# %%
""" set values """
# teff, requiv at prim or sec
# sma, period

b.set_value("teff@primary@component", value=25000)
# b.flip_constraint("teffratio@binary", solve_for = "teff@secondary")
# b.flip_constraint("teff@primary", solve_for = "teff@secondary")
b.set_value('ecc@binary@orbit@component', value=0.26)
b.set_value("teffratio@binary@component", value = 8.8)
# b.flip_constraint('teffratio@binary@component', solve_for='teff@primary')

# b.set_value("requiv@primary@component", value = 8.8)
# b.remove_constraint()
# b.set_value("teff@secondary@component", value=7000)

b.set_value("q@binary", value = 8.8)
b.set_value("sma@binary", value = 8.8)
b.set_value("per0@primary@component", value = 60)

### dont flip for teff ratio, try without flipping
 
# b.flip_constraint('requivsumfrac@binary@orbit', solve_for='sma')

""" we were here! try to get this running, with logg set (so it must be flipped)"""
b.flip_constraint('logg@primary', solve_for="requiv@primary") #its been flipped!
b.set_value("logg@primary@component", value = 3.8)

# %%
print(b.filter(context='component'))
# mass @ binary, solve for q @ binary
#inclination , effective t, r equiv all have a big effect, so does sma

# %%
### from the phoebe demos
b.set_value_all('ld_mode', 'manual')
b.set_value_all('ld_mode_bol', 'manual')
b.set_value_all('atm', 'blackbody')

b.flip_constraint('requivsumfrac', solve_for='requiv@secondary')
b.flip_constraint('teffratio@binary', solve_for='teff@secondary')
b.flip_constraint("esinw@binary@orbit", solve_for='ecc')
b.flip_constraint("ecosw@binary@orbit", solve_for='per0')

# %%
### only works AFTER lc periodogram
b.add_solver('estimator.ebai', solver='ebaiest', ebai_method = 'mlp', overwrite=True)
b['phase_bin@ebaiest@solver'] = False
# print(b['ebaiest'])
#mlp
b.run_solver(solver='ebaiest', solution= "ebaiest_sol",kind='ebai', overwrite=True)

### flip back to default for lc estimator ?
# print(b['ebaiest'])

### adopt
b.adopt_solution('ebaiest_sol')

# %%
#this one works!
# b.add_solver('estimator.lc_periodogram', solver= 'lc_periodo', overwrite=True)
# b.run_solver(solver= 'lc_periodo', solution = 'periodo_sol', kind='lc_periodogram', overwrite=True)
# print(b.get_solution('periodo_sol'))
b.adopt_solution('periodo_sol')
# Out:
# <ParameterSet: 23 parameters | contexts: dataset, component>

# %%
print(b.get_solution('ebaiest_sol'))

# %%
### add and run
# b.flip_constraint("ecc", solve_for='esinw@binary@orbit')
# b.flip_constraint("per0", solve_for='ecosw@binary@orbit')

b.set_value_all('ld_mode', 'lookup')
b.set_value_all('ld_mode_bol', 'lookup')
b['atm@secondary@compute'] = 'ck2004'
b['atm@primary@compute'] = 'ck2004'
b.set_value('pblum_mode', 'decoupled') #check the default is decoupled

b.add_solver('estimator.lc_geometry', solver= 'lc_geo', overwrite=True)
# b['analytical_model@lc_geo'] = 'two-gaussian' ##this throws up an error, requires additional arguments
b['analytical_model@lc_geo'] = 'polyfit'
print(b.get_parameter('requivsumfrac@binary@orbit@component'))
# print(b.get_solver(solver='lc_geo'))
print(b.run_checks())
b.run_solver(solver = 'lc_geo', solution = 'lc_geo_sol', kind='lc_geometry', overwrite=True)

### see if flipping should go here
# b.flip_constraint('requivsumfrac@binary@orbit', solve_for='sma') #its been flipped
# b.flip_constraint('requiv@primary@star', solve_for='logg') #its been flipped
#try mass flip q

#### adopt
b.adopt_solution('lc_geo_sol')

# %%
b.run_compute()

# %%
b.plot(show=True)
b.plot(x='phase', show=True)

# %%
# b.flip_constraint("ecc", solve_for='esinw@binary@orbit')
# b.flip_constraint("per0", solve_for='ecosw@binary@orbit')

# %%
print(b.filter(component='primary', context='component'))

# %%
### treats sun as a blackbody
b.set_value_all('ld_mode', 'manual')
b.set_value_all('ld_mode_bol', 'manual')
b['atm@secondary@compute'] = 'blackbody'
b['atm@primary@compute'] = 'blackbody'
b.set_value('pblum_mode', 'dataset-scaled')

### resets
b.set_value_all('ld_mode', 'lookup')
b.set_value_all('ld_mode_bol', 'lookup')
b['atm@secondary@compute'] = 'ck2004'
b['atm@primary@compute'] = 'ck2004'
b.set_value('pblum_mode', 'decoupled') #check the default is decoupled

### WARNING Atmosphere parameters out of bounds: ldatm=ck2004, teff=[7339.76135311], logg=[7.34496037], abun=[0.]
### mass@primary@component: 807.0356768836715 solMass
### expected logg = 3-4, high 3 to low 4

# %%
# print(b.filter())
# print(b.get_parameter('ld_mode_bol@primary', context='component'))
# print(b.get_parameter('atm@secondary', context='compute'))
# print(b.get_parameter('pblum_mode', context='dataset'))
# b.filter(context='system')

# %%
# print(b.get_value('teffratio@binary@orbit@component'))
# print(b.get_parameter('teffratio@binary@orbit@component'))
# print(b.get_parameter('teffratio@binary@orbit@constraint'))
# b.flip_constraint('teffratio@binary@orbit', solve_for='teff@primary') seconda

# print(b.get_value('requivsumfrac@binary@orbit@component'))
# print(b.get_parameter('requivsumfrac@binary@orbit@component'))
# # print(b.get_parameter('requivsumfrac@binary@orbit@constraint'))
# # b.flip_constraint('requivsumfrac@binary@orbit', solve_for='sma')

# b.add_solver('estimator.rv_geometry', solver='rv_geo', overwrite=True)
# print(b.filter(solver='rv_geo_sol'))
# b.run_solver('rv_geo', solution='rv_geo_sol')
# # print(b.filter(solution='rv_geo_sol'))

# pb.list_available_solvers(devel=False)

# %%
### for primary = A, secondary = B
# b.flip_constraint('logg@secondary', solve_for="requiv@secondary")
# b.set_value("logg@secondary@component", value = 4.0)
b.set_value('q@binary@component', value = 10.4)
b.flip_constraint("mass@primary", solve_for="q@binary")
# b.flip_constraint("mass@secondary", solve_for="q@binary")
b.set_value('mass@secondary@component', value = 8.1)

# %%
#set values before you run the solver
b.run_compute()
# ERROR: constraints ['logg@primary@star@constraint'] failed to run.  Address errors and try again.  Call run_failed_constraints to see the tracebacks. (1 affected parameters, affecting system,run_compute)

# %%
bls = lc.to_periodogram(method='bls')
bls.plot()
# peaks near 0.5
binned_periodo = bls.bin()

print(lombscargle.show_properties())
print(bls.show_properties())
